# %% [markdown]
# # 🪩 Rave visualiser
#
# Pick a **session + neuron + trial** and watch the animal rave its way to reward.
# Firing rate pulses the comet, fires shockwave rings, scrolls the bottom panel and strobes the scene.
# Outputs: inline video, MP4, GIF, and a long-exposure light-painting still.
#
# Palettes: `ice_uv` (default), `neon_noir`, `plasma_fire`, `rainbow`.

# %%
# %matplotlib inline
import importlib
import rave_visualiser as rv
importlib.reload(rv)
from IPython.display import HTML

# %% [markdown]
# ### What's available?
# Run this once to see mouse_recdays, sessions, #neurons and #trials (loads the ~3.5 GB pickle the first time).

# %%
rv.list_sessions()
# Out:
# Loading data_dic_for_yaren.pkl (one-off, ~3.5 GB)…
#
# ah08_20250613_20250615  (8 sessions)
#    session 0: 151 neurons,  5 trials, task=[3 2 7 1]
#    session 1: 151 neurons,  9 trials, task=[3 4 6 7]
#    session 2: 151 neurons,  7 trials, task=[7 5 1 6]
#    session 3: 151 neurons,  5 trials, task=[3 2 7 1]
#    session 4: 151 neurons, 11 trials, task=[6 4 9 2]
#    session 5: 151 neurons, 21 trials, task=[7 9 5 4]
#    session 6: 151 neurons, 10 trials, task=[7 3 1 5]
#    session 7: 151 neurons,  1 trials, task=[6 4 9 2]
#
# ah08_20250616_20250617  (8 sessions)
#    session 0: 164 neurons, 15 trials, task=[8 2 9 5]
#    session 1: 164 neurons, 13 trials, task=[5 2 7 8]
#    session 2: 164 neurons,  2 trials, task=[2 4 8 5]
#    session 3: 164 neurons,  9 trials, task=[8 2 9 5]
#    session 4: 164 neurons, 16 trials, task=[9 1 6 4]
#    session 5: 164 neurons, 15 trials, task=[7 8 3 6]
#    session 6: 164 neurons, 14 trials, task=[4 6 3 9]
#    session 7: 164 neurons,  0 trials, task=[9 1 6 4]
#
# ah08_20250618_20250619  (8 sessions)
#    session 0: 183 neurons, 22 trials, task=[3 1 4 2]
#    session 1: 183 neurons, 15 trials, task=[6 3 4 5]
#    session 2: 183 neurons, 21 trials, task=[5 4 1 6]
#    session 3: 183 neurons, 10 trials, task=[3 1 4 2]
#    session 4: 183 neurons, 23 trials, task=[6 5 8 1]
#    session 5: 183 neurons, 11 trials, task=[1 5 2 4]
#    session 6: 183 neurons,  7 trials, task=[2 7 9 5]
#    session 7: 183 neurons,  4 trials, task=[6 5 8 1]
#
# ah08_20250620_20250623  (8 sessions)
#    session 0: 108 neurons, 23 trials, task=[6 2 3 9]
#    session 1: 108 neurons, 22 trials, task=[6 2 8 1]
#    session 2: 108 neurons, 22 trials, task=[4 2 9 6]
#    session 3: 108 neurons,  0 trials, task=[6 2 3 9]
#    session 4: 108 neurons, 10 trials, task=[7 5 6 1]
#    session 5: 108 neurons, 18 trials, task=[6 5 4 1]
#    session 6: 108 neurons,  4 trials, task=[8 2 1 6]
#    session 7: 108 neurons,  2 trials, task=[7 5 6 1]
#
# ah08_20250624_20250625  (11 sessions)
#    session 0: 186 neurons, 14 trials, task=[5 2 8 7]
#    session 1: 186 neurons,  0 trials, task=None
#    session 2: 186 neurons,  7 trials, task=[4 6 1 9]
#    session 3: 186 neurons,  0 trials, task=[7 6 5 9]
#    session 4: 186 neurons,  0 trials, task=None
#    session 5: 186 neurons,  0 trials, task=None
#    session 6: 186 neurons, 10 trials, task=[6 7 8 2]
#    session 7: 186 neurons,  5 trials, task=[8 2 3 7]
#    session 8: 186 neurons,  1 trials, task=[9 6 1 5]
#    session 9: 186 neurons,  0 trials, task=None
#    session 10: 186 neurons,  0 trials, task=None
#
# ah10_20250613_20250615  (8 sessions)
#    session 0: 139 neurons, 18 trials, task=[5 9 7 1]
#    session 1: 139 neurons, 42 trials, task=[7 8 5 4]
#    session 2: 139 neurons, 22 trials, task=[4 3 5 9]
#    session 3: 139 neurons, 21 trials, task=[5 9 7 1]
#    session 4: 139 neurons, 37 trials, task=[4 6 3 5]
#    session 5: 139 neurons, 29 trials, task=[5 9 7 3]
#    session 6: 139 neurons, 25 trials, task=[9 4 1 7]
#    session 7: 139 neurons, 38 trials, task=[4 6 3 5]
#
# ah10_20250616_20250617  (8 sessions)
#    session 0: 154 neurons, 22 trials, task=[6 5 8 1]
#    session 1: 154 neurons, 25 trials, task=[1 7 6 5]
#    session 2: 154 neurons, 23 trials, task=[2 8 6 1]
#    session 3: 154 neurons, 27 trials, task=[6 5 8 1]
#    session 4: 154 neurons, 18 trials, task=[8 3 7 5]
#    session 5: 154 neurons, 25 trials, task=[8 1 4 6]
#    session 6: 154 neurons, 30 trials, task=[7 1 4 5]
#    session 7: 154 neurons, 24 trials, task=[8 3 7 5]
#
# ah10_20250618_20250619  (8 sessions)
#    session 0: 162 neurons, 21 trials, task=[5 4 9 1]
#    session 1: 162 neurons, 34 trials, task=[1 5 2 6]
#    session 2: 162 neurons, 30 trials, task=[2 7 8 4]
#    session 3: 162 neurons, 23 trials, task=[5 4 9 1]
#    session 4: 162 neurons, 25 trials, task=[5 3 8 1]
#    session 5: 162 neurons, 29 trials, task=[8 9 3 6]
#    session 6: 162 neurons, 31 trials, task=[9 3 6 5]
#    session 7: 162 neurons, 20 trials, task=[5 3 8 1]
#
# ah10_20250620_20250623  (9 sessions)
#    session 0: 153 neurons, 22 trials, task=[7 8 2 9]
#    session 1: 153 neurons, 26 trials, task=[2 7 8 1]
#    session 2: 153 neurons, 31 trials, task=[5 6 3 8]
#    session 3: 153 neurons, 25 trials, task=[7 8 2 9]
#    session 4: 153 neurons, 31 trials, task=[5 3 4 9]
#    session 5: 153 neurons, 32 trials, task=[4 1 8 2]
#    session 6: 153 neurons, 42 trials, task=[2 5 9 3]
#    session 7: 153 neurons,  3 trials, task=[5 3 4 9]
#    session 8: 153 neurons, 27 trials, task=[5 3 4 9]
#
# ah10_20250624_20250625  (10 sessions)
#    session 0: 164 neurons, 31 trials, task=[9 8 5 2]
#    session 1: 164 neurons,  0 trials, task=None
#    session 2: 164 neurons, 33 trials, task=[1 4 9 5]
#    session 3: 164 neurons, 23 trials, task=[6 7 8 4]
#    session 4: 164 neurons,  0 trials, task=None
#    session 5: 164 neurons,  0 trials, task=None
#    session 6: 164 neurons, 28 trials, task=[1 7 8 4]
#    session 7: 164 neurons, 21 trials, task=[8 3 9 7]
#    session 8: 164 neurons, 30 trials, task=[5 2 6 9]
#    session 9: 164 neurons,  0 trials, task=None
#
# ly05_20250613_20250615  (8 sessions)
#    session 0: 117 neurons,  8 trials, task=[6 1 3 9]
#    session 1: 117 neurons, 20 trials, task=[9 3 2 6]
#    session 2: 117 neurons,  4 trials, task=[9 1 2 5]
#    session 3: 117 neurons,  3 trials, task=[6 1 3 9]
#    session 4: 117 neurons, 22 trials, task=[1 7 2 5]
#    session 5: 117 neurons, 21 trials, task=[9 4 5 2]
#    session 6: 117 neurons,  5 trials, task=[5 8 7 4]
#    session 7: 117 neurons,  4 trials, task=[1 7 2 5]
#
# ly05_20250616_20250617  (8 sessions)
#    session 0: 116 neurons, 28 trials, task=[3 5 6 8]
#    session 1: 116 neurons, 16 trials, task=[5 2 7 3]
#    session 2: 116 neurons,  8 trials, task=[2 8 6 4]
#    session 3: 116 neurons, 18 trials, task=[3 5 6 8]
#    session 4: 116 neurons,  3 trials, task=[5 9 3 1]
#    session 5: 116 neurons,  7 trials, task=[1 4 6 8]
#    session 6: 116 neurons,  9 trials, task=[9 8 1 5]
#    session 7: 116 neurons,  7 trials, task=[5 9 3 1]
#
# ly05_20250618_20250619  (8 sessions)
#    session 0:  91 neurons,  8 trials, task=[5 9 7 6]
#    session 1:  91 neurons, 13 trials, task=[6 4 8 5]
#    session 2:  91 neurons,  3 trials, task=[5 2 9 1]
#    session 3:  91 neurons,  0 trials, task=[5 9 7 6]
#    session 4:  91 neurons,  6 trials, task=[7 4 5 1]
#    session 5:  91 neurons,  8 trials, task=[6 7 2 5]
#    session 6:  91 neurons,  1 trials, task=[1 3 2 6]
#    session 7:  91 neurons,  5 trials, task=[7 4 5 1]
#
# ly05_20250624_20250625  (10 sessions)
#    session 0:  74 neurons, 16 trials, task=[8 5 3 7]
#    session 1:  74 neurons,  0 trials, task=None
#    session 2:  74 neurons,  9 trials, task=[9 5 2 1]
#    session 3:  74 neurons,  0 trials, task=[5 8 9 1]
#    session 4:  74 neurons,  0 trials, task=None
#    session 5:  74 neurons,  0 trials, task=None
#    session 6:  74 neurons, 19 trials, task=[4 5 8 6]
#    session 7:  74 neurons, 10 trials, task=[8 5 1 4]
#    session 8:  74 neurons,  1 trials, task=[2 1 3 6]
#    session 9:  74 neurons,  0 trials, task=None
#
# ly06_20250613_20250615  (8 sessions)
#    session 0:  68 neurons,  4 trials, task=[6 3 5 4]
#    session 1:  68 neurons, 10 trials, task=[5 7 9 6]
#    session 2:  68 neurons, 15 trials, task=[3 5 9 8]
#    session 3:  68 neurons,  8 trials, task=[6 3 5 4]
#    session 4:  68 neurons, 28 trials, task=[2 6 3 8]
#    session 5:  68 neurons, 18 trials, task=[7 9 2 5]
#    session 6:  68 neurons, 40 trials, task=[4 2 5 6]
#    session 7:  68 neurons, 20 trials, task=[2 6 3 8]
#
# ly06_20250616_20250617  (8 sessions)
#    session 0:  79 neurons, 18 trials, task=[7 9 6 5]
#    session 1:  79 neurons, 33 trials, task=[5 3 6 4]
#    session 2:  79 neurons,  5 trials, task=[4 8 1 3]
#    session 3:  79 neurons, 24 trials, task=[7 9 6 5]
#    session 4:  79 neurons, 25 trials, task=[7 3 4 5]
#    session 5:  79 neurons, 11 trials, task=[2 7 1 6]
#    session 6:  79 neurons, 17 trials, task=[8 2 3 7]
#    session 7:  79 neurons, 14 trials, task=[7 3 4 5]
#
# ly06_20250618_20250619  (8 sessions)
#    session 0:  76 neurons, 17 trials, task=[7 5 9 3]
#    session 1:  76 neurons, 10 trials, task=[3 1 5 8]
#    session 2:  76 neurons,  8 trials, task=[8 5 1 9]
#    session 3:  76 neurons, 15 trials, task=[7 5 9 3]
#    session 4:  76 neurons, 21 trials, task=[9 1 8 3]
#    session 5:  76 neurons, 15 trials, task=[4 5 1 9]
#    session 6:  76 neurons, 20 trials, task=[9 5 8 4]
#    session 7:  76 neurons, 16 trials, task=[9 7 8 3]
#
# ly06_20250620_20250623  (8 sessions)
#    session 0:  67 neurons, 27 trials, task=[5 9 7 8]
#    session 1:  67 neurons,  5 trials, task=[9 2 8 1]
#    session 2:  67 neurons, 10 trials, task=[9 2 8 1]
#    session 3:  67 neurons,  2 trials, task=[9 5 8 2]
#    session 4:  67 neurons, 28 trials, task=[5 7 9 2]
#    session 5:  67 neurons, 30 trials, task=[2 7 8 5]
#    session 6:  67 neurons, 12 trials, task=[4 7 2 8]
#    session 7:  67 neurons, 15 trials, task=[5 7 9 2]
#
# ly06_20250624_20250625  (10 sessions)
#    session 0:  66 neurons, 28 trials, task=[3 4 5 6]
#    session 1:  66 neurons,  0 trials, task=None
#    session 2:  66 neurons, 18 trials, task=[3 1 2 5]
#    session 3:  66 neurons, 20 trials, task=[4 9 5 3]
#    session 4:  66 neurons,  0 trials, task=None
#    session 5:  66 neurons,  0 trials, task=None
#    session 6:  66 neurons, 24 trials, task=[6 5 8 9]
#    session 7:  66 neurons,  7 trials, task=[4 7 1 8]
#    session 8:  66 neurons, 21 trials, task=[5 3 9 2]
#    session 9:  66 neurons,  0 trials, task=None
#
# ly07_20250613_20250615  (8 sessions)
#    session 0:  73 neurons, 31 trials, task=[9 8 5 2]
#    session 1:  73 neurons, 27 trials, task=[1 2 6 5]
#    session 2:  73 neurons, 29 trials, task=[6 9 5 4]
#    session 3:  73 neurons, 26 trials, task=[9 8 5 2]
#    session 4:  73 neurons, 33 trials, task=[3 5 4 6]
#    session 5:  73 neurons,  9 trials, task=[1 3 2 8]
#    session 6:  73 neurons, 18 trials, task=[3 7 8 5]
#    session 7:  73 neurons, 30 trials, task=[3 5 4 6]
#
# ly07_20250616_20250617  (8 sessions)
#    session 0:  88 neurons, 11 trials, task=[7 9 4 5]
#    session 1:  88 neurons, 16 trials, task=[8 5 1 6]
#    session 2:  88 neurons, 41 trials, task=[4 1 9 5]
#    session 3:  88 neurons,  2 trials, task=[7 9 4 5]
#    session 4:  88 neurons, 21 trials, task=[3 4 6 1]
#    session 5:  88 neurons, 24 trials, task=[8 6 9 4]
#    session 6:  88 neurons, 20 trials, task=[6 7 8 5]
#    session 7:  88 neurons, 17 trials, task=[3 4 6 1]
#
# ly07_20250618_20250619  (8 sessions)
#    session 0:  88 neurons, 12 trials, task=[8 2 9 7]
#    session 1:  88 neurons, 12 trials, task=[5 3 1 4]
#    session 2:  88 neurons, 27 trials, task=[9 2 4 6]
#    session 3:  88 neurons,  8 trials, task=[8 2 9 7]
#    session 4:  88 neurons, 12 trials, task=[7 5 2 9]
#    session 5:  88 neurons, 17 trials, task=[8 5 7 2]
#    session 6:  88 neurons, 19 trials, task=[2 8 6 1]
#    session 7:  88 neurons, 22 trials, task=[7 5 2 9]
#
# ly07_20250620_20250623  (8 sessions)
#    session 0:  89 neurons, 26 trials, task=[4 8 5 7]
#    session 1:  89 neurons, 15 trials, task=[7 8 2 6]
#    session 2:  89 neurons, 32 trials, task=[5 3 6 2]
#    session 3:  89 neurons, 20 trials, task=[4 8 5 7]
#    session 4:  89 neurons, 37 trials, task=[8 7 6 4]
#    session 5:  89 neurons, 53 trials, task=[4 6 8 5]
#    session 6:  89 neurons, 20 trials, task=[9 3 8 6]
#    session 7:  89 neurons,  8 trials, task=[8 7 6 4]
#
# ly07_20250624_20250625  (10 sessions)
#    session 0:  86 neurons, 24 trials, task=[2 6 4 8]
#    session 1:  86 neurons,  0 trials, task=None
#    session 2:  86 neurons, 43 trials, task=[3 9 5 2]
#    session 3:  86 neurons, 10 trials, task=[5 7 4 6]
#    session 4:  86 neurons,  0 trials, task=None
#    session 5:  86 neurons,  0 trials, task=None
#    session 6:  86 neurons, 48 trials, task=[8 6 5 3]
#    session 7:  86 neurons, 36 trials, task=[6 7 5 3]
#    session 8:  86 neurons,  0 trials, task=[1 4 5 9]
#    session 9:  86 neurons,  0 trials, task=None

# %% [markdown]
# ### Choose your set

# %%
MOUSE_RECDAY = 'ly07_20250616_20250617'
SESSION      = 1
NEURON       = 20
TRIAL        = 2
PALETTE      = 'rainbow'   # ice_uv | neon_noir | plasma_fire | rainbow
FPS          = 30
SPEEDUP      = 2.0        # 3x faster than real time

session = rv.load_session(MOUSE_RECDAY, SESSION)
print(f"{session['label']}: {session['n_neurons']} neurons, {session['n_trials']} trials, "
      f"towers visited: {sorted(session['node_xy'])}")
# Out:
# ly07_20250616_20250617_s1: 88 neurons, 16 trials, towers visited: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Render + play inline

# %%
anim, fig = rv.render_rave(session, neuron=NEURON, trial=TRIAL,
                           palette=PALETTE, fps=FPS, speedup=SPEEDUP)
HTML(anim.to_html5_video())
# Out:
# <video width="700" height="840" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Save MP4 + GIF

# %%
base = f"{session['label']}_n{NEURON}_t{TRIAL}_{PALETTE}"
rv.save_outputs(anim, base, fps=FPS)
# Out:
# saved mp4 → /ceph/behrens/adam_harris/Taskspace_abstraction_lEC/code/rave_output/ly07_20250616_20250617_s1_n20_t2_rainbow.mp4
# saved gif → /ceph/behrens/adam_harris/Taskspace_abstraction_lEC/code/rave_output/ly07_20250616_20250617_s1_n20_t2_rainbow.gif
# {'mp4': '/ceph/behrens/adam_harris/Taskspace_abstraction_lEC/code/rave_output/ly07_20250616_20250617_s1_n20_t2_rainbow.mp4',
#  'gif': '/ceph/behrens/adam_harris/Taskspace_abstraction_lEC/code/rave_output/ly07_20250616_20250617_s1_n20_t2_rainbow.gif'}

# %% [markdown]
# ### Long-exposure light-painting still

# %%
rv.render_long_exposure(session, neuron=NEURON, trial=TRIAL,
                        palette=PALETTE, speedup=SPEEDUP, fps=FPS);
